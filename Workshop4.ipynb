# %% [markdown]
# <a href="https://colab.research.google.com/github/oakabc/DEA/blob/main/Workshop4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
uri = 'score_ageb no column.xlsx'
df = pd.read_excel(uri)
df
# Out:
#   Kobkiat  25  35  1
# 0   ณิแนน  22  26  1
# 1   จอห์น  25  32  2
# 2     Tim  35  29  2
# 3   Steal  32  27  1
# 4    Mark  28  30  2
# 5     แดง  23  35  1
# 6      ดำ  26  25  2
# 7     ขาว  25  28  1
# 8     Bob  28  30  2

# %%
mycolumns = ['Student','MathScore','CompScore','Section'] # must be matched with number of columns
df = pd.read_excel (uri, names=mycolumns, index_col = 'Student')
df
# Out:
#          MathScore  CompScore  Section
# Student
# ณิแนน           22         26        1
# จอห์น           25         32        2
# Tim             35         29        2
# Steal           32         27        1
# Mark            28         30        2
# แดง             23         35        1
# ดำ              26         25        2
# ขาว             25         28        1
# Bob             28         30        2

# %%
df.loc[['Tim','Mark'],['MathScore','Section']]
# Out:
#          MathScore  Section
# Student
# Tim             35        2
# Mark            28        2

# %%
uri = 'score_ageb.csv'
# df = pd.read_csv(uri)
df = pd.read_csv(uri, encoding = 'utf-8') # To support Thai language (as well as other language)
df.head() # display first 5 rows
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %%
uri = 'score_ageb.csv'
df = pd.read_csv(uri, index_col = 'Name')
df.head()
# Out:
#          Age  Score  Section
# Name
# Kobkiat   25     35        1
# ณิแนน     22     26        1
# จอห์น     25     32        2
# Tim       35     29        2
# Steal     32     27        1

# %%
uri = 'score_ageb.csv'
#cols = ['Name', 'Score']
# cols = [0,2]
df = pd.read_csv(uri, usecols=[0,1])
df
# Out:
#       Name  Age
# 0  Kobkiat   25
# 1    ณิแนน   22
# 2    จอห์น   25
# 3      Tim   35
# 4    Steal   32
# 5     Mark   28
# 6      แดง   23
# 7       ดำ   26
# 8      ขาว   25
# 9      Bob   28

# %%
uri = 'score_ageb no column.csv'
df = pd.read_csv(uri)
df
# Out:
#   Kobkiat  25  35  1
# 0   ณิแนน  22  26  1
# 1   จอห์น  25  32  2
# 2     Tim  35  29  2
# 3   Steal  32  27  1
# 4    Mark  28  30  2
# 5     แดง  23  35  1
# 6      ดำ  26  25  2
# 7     ขาว  25  28  1
# 8     Bob  28  30  2

# %%
columns = ['Student', 'Math', 'Comp', 'Year']
df = pd.read_csv(uri, names = columns, index_col = 'Student')
df
# Out:
#          Math  Comp  Year
# Student
# Kobkiat    25    35     1
# ณิแนน      22    26     1
# จอห์น      25    32     2
# Tim        35    29     2
# Steal      32    27     1
# Mark       28    30     2
# แดง        23    35     1
# ดำ         26    25     2
# ขาว        25    28     1
# Bob        28    30     2

# %%
import pandas as pd
uri = 'score_ageb.csv'
df = pd.read_csv(uri)
df.head() # display 5 rows by default
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %%
df.head(3)
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2

# %%
df.tail(3)
# Out:
#   Name  Age  Score  Section
# 7   ดำ   26     25        2
# 8  ขาว   25     28        1
# 9  Bob   28     30        2

# %%
df.sample(5)
# Out:
#       Name  Age  Score  Section
# 2    จอห์น   25     32        2
# 0  Kobkiat   25     35        1
# 8      ขาว   25     28        1
# 1    ณิแนน   22     26        1
# 4    Steal   32     27        1

# %%
df.describe()
# Out:
#              Age      Score    Section
# count  10.000000  10.000000  10.000000
# mean   26.900000  29.700000   1.500000
# std     4.012481   3.465705   0.527046
# min    22.000000  25.000000   1.000000
# 25%    25.000000  27.250000   1.000000
# 50%    25.500000  29.500000   1.500000
# 75%    28.000000  31.500000   2.000000
# max    35.000000  35.000000   2.000000

# %%
df.dtypes
# Out:
# Name       object
# Age         int64
# Score       int64
# Section     int64
# dtype: object

# %%
uri = 'score_ageb.csv'
df = pd.read_csv(uri, dtype={'Section':str}) # Change Section to String at reading stage
df.dtypes
# Out:
# Name       object
# Age         int64
# Score       int64
# Section    object
# dtype: object

# %%
df.describe()
# Out:
#              Age      Score
# count  10.000000  10.000000
# mean   26.900000  29.700000
# std     4.012481   3.465705
# min    22.000000  25.000000
# 25%    25.000000  27.250000
# 50%    25.500000  29.500000
# 75%    28.000000  31.500000
# max    35.000000  35.000000

# %%
import pandas as pd
uri = 'score_ageb.csv'
df = pd.read_csv(uri)
df.head() # display 5 rows by default
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %%
df.describe()
# Out:
#              Age      Score    Section
# count  10.000000  10.000000  10.000000
# mean   26.900000  29.700000   1.500000
# std     4.012481   3.465705   0.527046
# min    22.000000  25.000000   1.000000
# 25%    25.000000  27.250000   1.000000
# 50%    25.500000  29.500000   1.500000
# 75%    28.000000  31.500000   2.000000
# max    35.000000  35.000000   2.000000

# %%
df.Section = df.Section.astype('category')

# %%
df.Section
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    1
# 5    2
# 6    1
# 7    2
# 8    1
# 9    2
# Name: Section, dtype: category
# Categories (2, int64): [1, 2]

# %%
df.describe()
# Out:
#              Age      Score
# count  10.000000  10.000000
# mean   26.900000  29.700000
# std     4.012481   3.465705
# min    22.000000  25.000000
# 25%    25.000000  27.250000
# 50%    25.500000  29.500000
# 75%    28.000000  31.500000
# max    35.000000  35.000000

# %%
uri = 'score_ageb.csv'
df = pd.read_csv(uri)
df
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1
# 5     Mark   28     30        2
# 6      แดง   23     35        1
# 7       ดำ   26     25        2
# 8      ขาว   25     28        1
# 9      Bob   28     30        2

# %%
df.Name[0:3] #select column 'Name' from row 0 to 2
# Out:
# 0    Kobkiat
# 1      ณิแนน
# 2      จอห์น
# Name: Name, dtype: object

# %%
df.Name[1]
# Out:
# 'ณิแนน'

# %%
df[['Name','Score']][1:4]
# Out:
#     Name  Score
# 1  ณิแนน     26
# 2  จอห์น     32
# 3    Tim     29

# %%
df[3:6] #row-based
# Out:
#     Name  Age  Score  Section
# 3    Tim   35     29        2
# 4  Steal   32     27        1
# 5   Mark   28     30        2

# %%
df[3:6].Age #row-based + column
# Out:
# 3    35
# 4    32
# 5    28
# Name: Age, dtype: int64

# %%
df
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1
# 5     Mark   28     30        2
# 6      แดง   23     35        1
# 7       ดำ   26     25        2
# 8      ขาว   25     28        1
# 9      Bob   28     30        2

# %%
df.loc[1:4,'Age':'Section'] #inclusive
# Out:
#    Age  Score  Section
# 1   22     26        1
# 2   25     32        2
# 3   35     29        2
# 4   32     27        1

# %%
df
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1
# 5     Mark   28     30        2
# 6      แดง   23     35        1
# 7       ดำ   26     25        2
# 8      ขาว   25     28        1
# 9      Bob   28     30        2

# %%
df.iloc[1] #row-based using interger index
# Out:
# Name       ณิแนน
# Age           22
# Score         26
# Section        1
# Name: 1, dtype: object

# %%
df.iloc[1]['Age'] # = df.iloc[1,1]
# Out:
# np.int64(22)

# %%
df.iloc[1,1]
# Out:
# np.int64(22)

# %%
df.iloc[1:4]
# Out:
#     Name  Age  Score  Section
# 1  ณิแนน   22     26        1
# 2  จอห์น   25     32        2
# 3    Tim   35     29        2

# %%
df.iloc[1:4, 1:]
# Out:
#    Age  Score  Section
# 1   22     26        1
# 2   25     32        2
# 3   35     29        2
